# %%
import pandas as pd
from matplotlib import font_manager
from spandas.preprocessing import data_preprocessing, Loggs

# %%
# Здесь пример быстрого использования библиотеки

# %%
font_dirs = ['fonts']
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
 
for font_file in font_files:
    font_manager.fontManager.addfont(font_file)

# %%
url = "ecology.xlsx"
df = pd.read_excel(url)

df.head()
# Out:
#    id                            a4a      a6a                             a2  \
# 0  22  Готовые Металлические Изделия    Малый  Центральный Федеральный округ
# 1  29          Машины и оборудование  Крупный  Центральный Федеральный округ
# 2  34            Другое Производство  Средний  Центральный Федеральный округ
# 3  50  Готовые Металлические Изделия    Малый  Центральный Федеральный округ
# 4  56                  Другие Услуги    Малый  Центральный Федеральный округ
#
#               a0                                                 b1    b5  \
# 0   Производство  Акционерная компания с неторгуемыми акциями ил...  2007
# 1   Производство  Акционерная компания с неторгуемыми акциями ил...  2002
# 2   Производство  Акционерная компания с неторгуемыми акциями ил...  2005
# 3  Другие услуги  Акционерная компания с неторгуемыми акциями ил...  2015
# 4  Другие услуги  Акционерная компания с неторгуемыми акциями ил...  2002
#
#    b7a                                              d1a1x  g1a  ... BMGc23i  \
# 0  Нет  Производство Готовых Строительных Металлически...    0  ...      Да
# 1  Нет                Производство Насосов И Компрессоров    0  ...     Нет
# 2  Нет  Производство Алюминиевых И Медных Проводов, Си...  100  ...      Да
# 3  Нет               Строительство жилых и нежилых зданий    0  ...     Нет
# 4  Нет                     Оптовая Продажа Офисной Мебели    0  ...      Да
#
#         BMGc23j                             BMGc24 BMGc25  \
# 0           Нет  Модернизация машин и оборудования     Да
# 1           Нет  Модернизация машин и оборудования    Нет
# 2       Не знаю                                NaN    Нет
# 3           Нет                                NaN    Нет
# 4  Не применимо  Модернизация машин и оборудования    Нет
#
#                                               BMGc27 BMGd6 BMGd7    BMGe1  \
# 0                                                NaN   Нет   Нет   100000
# 1  Не является приоритетом по сравнению с другими...   Нет   Нет   160000
# 2                       Нехватка финансовых ресурсов   Нет   Нет  Не знаю
# 3               Операционный и/ или технический риск   Нет   Нет  Не знаю
# 4                       Нехватка финансовых ресурсов   Нет   Нет   100000
#
#      BMGe2 BMGe2u
# 0    20000  Литры
# 1    18500  Литры
# 2  Не знаю    NaN
# 3  Не знаю    NaN
# 4    10000  Литры
#
# [5 rows x 48 columns]

# %%
exc = ['id', 'b5', 'g1a', 'j30_environment_pos']

# %%
fig, axes = subplots(2)

axes[0].plot(x=range(10), y=range(10))
axes[0].set_title("График тестовый")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 fig, axes = subplots(2)
# ----> 3 axes[0].plot(x=range(10), y=range(10))
#       4 axes[0].set_title("График тестовый")
#
# File c:\Users\Vex1cK\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\Users\Vex1cK\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:246, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     244 for pos_only in "xy":
#     245     if pos_only in kwargs:
# --> 246         raise _api.kwarg_error(self.command, pos_only)
#     248 if not args:
#     249     return
#
# TypeError: plot() got an unexpected keyword argument 'x'

# %%
clear_df, deleted = data_preprocessing(df, exclude=exc)
# clear_df
# Out:
#  ____         _              _              _                _
# / ___|   ___ | |  ___   ___ | |_   ___   __| |   ___   ___  | | ___  _
# \___ \  / _ \| | / _ \ / __|| __| / _ \ / _` |  / __| / _ \ | |/ __|(_)
#  ___) ||  __/| ||  __/| (__ | |_ |  __/| (_| | | (__ | (_) || |\__ \ _
# |____/  \___||_| \___| \___| \__| \___| \__,_|  \___| \___/ |_||___/(_)
#
#
#
# n2a | n2e | n2b | n2f | n2i | n2p | BMGe1 | BMGe2
#
#
#
#
#  _____  _____  _____  _____  _____  _____  _____  _____  _____  _____
# |_____||_____||_____||_____||_____||_____||_____||_____||_____||_____|
#
# column: n2a => deleted: 154
# column: n2e => deleted: 76
# column: n2b => deleted: 72
# column: n2f => deleted: 25
# column: n2i => deleted: 8
# column: n2p => deleted: 18
# column: BMGe1 => deleted: 29
# column: BMGe2 => deleted: 63
# __        __    _     ____
# \ \      / /   / \   / ___|  _
#  \ \ /\ / /   / _ \  \___ \ (_)
#   \ V  V /   / ___ \  ___) | _
#    \_/\_/   /_/   \_\|____/ (_)
#
#
#
#
#
#
#  _____  _____  _____  _____  _____  _____  _____  _____  _____  _____
# |_____||_____||_____||_____||_____||_____||_____||_____||_____||_____|
#
#  ____   _____   ____     _     __  __  _____
# | __ ) | ____| / ___|   / \   |  \/  || ____| _
# |  _ \ |  _|  | |      / _ \  | |\/| ||  _|  (_)
# | |_) || |___ | |___  / ___ \ | |  | || |___  _
# |____/ |_____| \____|/_/   \_\|_|  |_||_____|(_)

# %%
deleted
# Out:
# {'n2a': {'count': 154,
#   'deleted': {1: '150000000',
#    14: '150000000',
#    37: '160000000',
#    47: '270000000',
#    67: '240000000',
#    75: '150000000',
#    89: '200400000',
#    90: '400000000',
#    108: '900000000',
#    124: '3000000000',
#    143: '180000000',
#    159: '200000000',
#    184: '950000000',
#    188: '155000000',
#    225: '185000000',
#    258: '200000000',
#    345: '270000000',
#    363: '190000000',
#    378: '240600000',
#    394: '190000000',
#    398: '460000000',
#    399: '1000000000',
#    485: '188000000',
#    505: '760000000',
#    508: '480000000',
#    568: '396000000',
#    582: '250000000',
#    791: '4213205000',
#    863: '2000000000',
#    961: '155000000',
#    964: '164000000',
#    976: '150000000',
#    978: '480000000',
#    981: '170000000',
#    982: '248000000',
#    989: '395000000',
#    991: '700000000',
#    992: '200000000',
#    993: '200000000',
#    995: '150000000',
#    1002: '185000000',
#    1004: '480000000',
#    1005: '185000000',
#    1006: '714000000',
#    1009: '250000000',
#    1010: '412000000',
#    1014: '400000000',
#    1016: '200000000',
#    1018: '250000000',
#    1022: '145000000',
#    1024: '450000000',
#    1027: '900000000',
#    1028: '180000000',
#    1032: '500000000',
#    1034: '460790000',
#    1037: '200000000',
#    1038: '350000000',
#    1042: '470000000',
#    1049: '230000000',
#    1050: '243674000',
#    1053: '280000000',
#    1054: '300000000',
#    1056: '560000000',
#    1058: '370000000',
#    1059: '480000000',
#    1061: '250000000',
#    1066: '500000000',
#    1068: '447000000',
#    1071: '300000000',
#    1073: '150000000',
#    1075: '200000000',
#    1076: '500000000',
#    1078: '560000000',
#    1079: '387000000',
#    1082: '500000000',
#    1083: '365000000',
#    1087: '245000000',
#    1089: '460000000',
#    1093: '550000000',
#    1095: '400000000',
#    1096: '550000000',
#    1097: '150000000',
#    1098: '150000000',
#    1099: '500000000',
#    1100: '285000000',
#    1101: '180000000',
#    1102: '400000000',
#    1103: '400000000',
#    1104: '360000000',
#    1105: '550000000',
#    1107: '150000000',
#    1111: '290000000',
#    1115: '1300000000',
#    1118: '950000000',
#    1120: '1000000000',
#    1121: '450000000',
#    1122: '150000000',
#    1124: '180000000',
#    1126: '400000000',
#    1127: '645000000',
#    1128: '350000000',
#    1130: '390600000',
#    1132: '640380000',
#    1133: '200000000',
#    1136: '200800000',
#    1137: '411000000',
#    1140: '300000000',
#    1141: '356200000',
#    1142: '187000000',
#    1143: '470000000',
#    1146: '250000000',
#    1148: '650000000',
#    1150: '250000000',
#    1152: '250000000',
#    1153: '735000000',
#    1157: '360700000',
#    1159: '262560000',
#    1163: '500000000',
#    1167: '208800000',
#    1169: '310000000',
#    1172: '640000000',
#    1173: '500000000',
#    1174: '345000000',
#    1181: '460000000',
#    1184: '200000000',
#    1186: '250000000',
#    1187: '800000000',
#    1188: '690000000',
#    1189: '1000000000',
#    1191: '745000000',
#    1192: '3700000000',
#    1196: '3000000000',
#    1203: '600000000',
#    1205: '400000000',
#    1206: '500000000',
#    1207: '500000000',
#    1208: '1200000000',
#    1209: '380000000',
#    1211: '600000000',
#    1212: '400000000',
#    1215: '1500000000',
#    1216: '300000000',
#    1218: '1000000000',
#    1221: '157722000',
#    1223: '3800000000',
#    1226: '50000000000',
#    1230: '350000000',
#    1233: '180000000',
#    1240: '240000000',
#    1245: '2000000000',
#    1246: '2200000000',
#    1249: '173840802',
#    1254: '320000000',
#    1317: '392400000'}},
#  'n2e': {'count': 76,
#   'deleted': {2: '78000000',
#    8: '120000000',
#    9: '300000000',
#    15: '1200000000',
#    27: '384000000',
#    30: '190000000',
#    34: '84000000',
#    40: '144000000',
#    49: '160000000',
#    55: '85000000',
#    56: '100000000',
#    68: '288000000',
#    82: '85000000',
#    120: '133000000',
#    135: '115000000',
#    318: '150000000',
#    319: '230000000',
#    421: '240000000',
#    592: '135000000',
#    605: '680000000',
#    748: '100000000',
#    763: '100000000',
#    790: '80000000',
#    797: '95000000',
#    823: '108000000',
#    826: '80000000',
#    833: '113000000',
#    834: '150000000',
#    844: '100000000',
#    854: '240000000',
#    857: '150000000',
#    864: '90000000',
#    865: '119000000',
#    872: '150000000',
#    873: '108000000',
#    880: '180000000',
#    882: '400000000',
#    884: '153128001',
#    919: '160000000',
#    921: '200000000',
#    928: '330000000',
#    945: '650000000',
#    947: '275000000',
#    949: '350000000',
#    956: '400000000',
#    967: '120000000',
#    970: '250000000',
#    971: '300000000',
#    975: '700000000',
#    983: '600000000',
#    987: '690000000',
#    988: '90000000',
#    994: '700000000',
#    997: '580000000',
#    1000: '260000000',
#    1021: '200000000',
#    1039: '700000000',
#    1040: '900000000',
#    1063: '900000000',
#    1065: '100000000',
#    1070: '314500000',
#    1080: '500000000',
#    1081: '950000000',
#    1088: '670000000',
#    1108: '130000000',
#    1131: '373000000',
#    1135: '270000000',
#    1144: '1200000000',
#    1145: '150000000',
#    1147: '250000000',
#    1178: '1500000000',
#    1197: '157800000',
#    1202: '120000000',
#    1204: '140000000',
#    1222: '480000000',
#    1247: '120000000'}},
#  'n2b': {'count': 72,
#   'deleted': {12: '2600000',
#    20: '1800000',
#    32: '2000000',
#    48: '1500000',
#    54: '2000000',
#    60: '1500000',
#    80: '3000000',
#    102: '1500000',
#    104: '100000000',
#    105: '2000000',
#    111: '1500000',
#    113: '1500000',
#    126: '1500000',
#    127: '1500000',
#    132: '1600000',
#    133: '4600000',
#    134: '1500000',
#    149: '2000000',
#    247: '3600000',
#    334: '2300000',
#    336: '3500000',
#    346: '2700000',
#    348: '2400000',
#    349: '1500000',
#    358: '1700000',
#    392: '1500000',
#    400: '2500000',
#    416: '1500000',
#    461: '1500000',
#    478: '3630000',
#    482: '7265000',
#    484: '6000000',
#    486: '12000000',
#    499: '8000000',
#    511: '8000000',
#    552: '30000000',
#    565: '2000000',
#    580: '2600000',
#    599: '1500000',
#    662: '2400000',
#    688: '2300000',
#    697: '8900000',
#    702: '2100000',
#    737: '4000000',
#    738: '3000000',
#    741: '3000000',
#    756: '3800000',
#    796: '2500000',
#    804: '1500000',
#    810: '1800000',
#    871: '3000000',
#    958: '1500000',
#    959: '3600000',
#    966: '2000000',
#    973: '3200000',
#    999: '3000000',
#    1003: '1500000',
#    1007: '5500000',
#    1011: '4000000',
#    1019: '1600000',
#    1091: '12108000',
#    1092: '1800000',
#    1185: '4500000',
#    1227: '8000000',
#    1232: '2000000',
#    1250: '1500000',
#    1253: '1700000',
#    1278: '1800000',
#    1288: '2000000',
#    1314: '2700000',
#    1318: '5500000',
#    1319: '4000000'}},
#  'n2f': {'count': 25,
#   'deleted': {19: '2000000',
#    63: '3600000',
#    77: '110000000',
#    93: '11000000',
#    98: '2160000',
#    122: '1800000',
#    138: '1700000',
#    142: '1600000',
#    164: '2100000',
#    170: '1650000',
#    405: '6000000',
#    451: '1800000',
#    481: '6180168',
#    491: '10000000',
#    493: '7949004',
#    549: '1700000',
#    550: '10000000',
#    564: '4000000',
#    588: '2900000',
#    699: '18000000',
#    727: '5000000',
#    879: '8000000',
#    946: '3000000',
#    962: '9800000',
#    1052: '3000000'}},
#  'n2i': {'count': 8,
#   'deleted': {11: '200000000',
#    125: '58800000',
#    129: '380000000',
#    136: '140000000',
#    248: '45000000',
#    329: '140000000',
#    1283: '145000000',
#    1285: '68000000'}},
#  'n2p': {'count': 18,
#   'deleted': {183: '78000000',
#    320: '79100000',
#    376: '80000000',
#    384: '156000000',
#    434: '86000000',
#    802: '91000000',
#    827: '113000000',
#    835: '181020000',
#    878: '105000000',
#    881: '80000000',
#    931: '82000000',
#    938: '118030000',
#    951: '78000000',
#    955: '171560000',
#    965: '78760000',
#    998: '100000000',
#    1015: '150000000',
#    1210: '81000000'}},
#  'BMGe1': {'count': 29,
#   'deleted': {10: '170000',
#    24: '180000',
#    26: '120000',
#    35: '166000',
#    53: '150000',
#    79: '150000',
#    84: '150000',
#    87: '175000',
#    99: '250000',
#    103: '300000',
#    106: '130000',
#    115: '150000',
#    117: '150000',
#    123: '150000',
#    415: '250000',
#    419: '250000',
#    651: '400000',
#    698: '166000',
#    703: '142000',
#    724: '140000',
#    747: '166000',
#    867: '190000',
#    895: '250000',
#    911: '2000000',
#    927: '314000',
#    942: '160000',
#    1023: '500000',
#    1047: '250000',
#    1199: '1000000'}},
#  'BMGe2': {'count': 63,
#   'deleted': {0: '20000',
#    4: '10000',
#    6: '5500',
#    25: '36000',
#    29: '13000',
#    33: '17000',
#    36: '18000',
#    39: '6000',
#    50: '12000',
#    57: '13000',
#    58: '150000',
#    59: '200',
#    61: '50000',
#    69: '2000',
#    72: '3600',
#    76: '30000',
#    91: '16000',
#    92: '25000',
#    94: '2000',
#    96: '5500',
#    97: '9000',
#    109: '150000',
#    112: '7200',
#    114: '11000',
#    116: '7400',
#    119: '16000',
#    128: '15000',
#    171: '700',
#    333: '60',
#    337: '410',
#    397: '2000',
#    402: '500',
#    410: '30',
#    438: '20',
#    480: '14000',
#    483: '46000',
#    487: '10080',
#    496: '17000',
#    534: '18000',
#    535: '250000',
#    540: '600',
#    545: '2500',
#    548: '2000',
#    589: '15',
#    590: '20000',
#    639: '500',
#    683: '2300',
#    689: '600',
#    718: '10000',
#    730: '3000',
#    735: '5000',
#    751: '6000',
#    753: '552',
#    759: '2500',
#    787: '18000',
#    832: '120009',
#    850: '20000',
#    892: '76',
#    916: '15000',
#    980: '4800',
#    1119: '15000',
#    1171: '20000',
#    1277: '3000'}}}
